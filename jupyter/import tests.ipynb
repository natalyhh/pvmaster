# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
PATH18 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/*.dat"

# %%
datafiles = glob.glob(PATH18)
datafiles.sort()

# %%
datafiles
# Out:
# ['/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_2.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_3.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_4.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_5.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_6.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_7.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_8.dat']

# %%
df1 = pd.read_csv(datafiles[0], 
                    usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT',
                             'wind_speed', 
                             'wind_direction']
                )
# Out:
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df3 = pd.read_csv(datafiles[0], 
                    usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT',
                             'wind_speed', 
                             'wind_direction']
                )[['TIMESTAMP','wind_speed', 
                             'wind_direction',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT']]
# Out:
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df3
# Out:
#                    TIMESTAMP wind_speed wind_direction  RECORD  DfHIP_SPN1  \
# 0        2017-12-13 14:32:40       1.14             35  506255       637.6
# 1        2017-12-13 14:32:41        1.3             51  506256       639.6
# 2        2017-12-13 14:32:42       1.18             98  506257       639.6
# 3        2017-12-13 14:32:43       0.96            285  506258       640.7
# 4        2017-12-13 14:32:44       0.91            258  506259       642.4
# ...                      ...        ...            ...     ...         ...
# 3441918  2018-01-17 18:57:02       2.47            354   94538       273.5
# 3441919  2018-01-17 18:57:03       2.07            348   94539       271.7
# 3441920  2018-01-17 18:57:04        1.5            342   94540       271.7
# 3441921  2018-01-17 18:57:05       1.57              6   94541       270.2
# 3441922  2018-01-17 18:57:06       1.98              2   94542       268.6
#
# ...

# %%
df1
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 0            1047.0      1028.0     1012.0         1019.0        767.0
# ...

# %%
    df1 = df1.fillna('-9999')

# %%
df1.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100            object
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100           object
# TGHIP_SI02pt100_dirty     object
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1          object
# dtype: object

# %%
df1
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 0            1047.0      1028.0     1012.0         1019.0        767.0
# ...

# %%
df2 = df1

# %%
df2.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100            object
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100           object
# TGHIP_SI02pt100_dirty     object
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1          object
# dtype: object

# %%
    df2 = df2.fillna('-9999')

# %%
index = df2[df2.wind_direction=='-9999']

# %%
index
# Out:
# Empty DataFrame
# Columns: [TIMESTAMP, RECORD, DNI_SHP1, LW_SGR4, GHIT_SMP22, GHIP_SMP22, GHIP_SMP11, GHIP_SPN1, GHIP_SI02pt100, DfHIT_SMP22, DfHIRP_SMP11, DfHIP_SPN1, TGIP_SMP11_VENT, TGHIP_SI02pt100, TGHIP_SI02pt100_dirty, wind_speed, wind_direction, DIF_GLO_REF_SPN1]
# Index: []

# %%
df2.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630      17.6    405.0       695.1       717.8
# 376  2017-12-13 14:38:56  506631      17.6    405.0       693.9       716.3
# 377  2017-12-13 14:38:57  506632      17.5    405.1       693.2       715.3
# 378  2017-12-13 14:38:58  506633      17.5    405.1       692.8       714.6
#
#      GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# 375       713.9      726.6          686.2        675.9         571.0
# 376       712.5      723.5          684.8        675.2         571.0
# 377       712.0      721.1          684.1        674.5         570.0
# 378       711.3      723.0          683.7        673.7         570.0
#
#      DfHIP_SPN1  TGIP_SMP11_VENT TGHIP_SI02pt100 TGHIP_SI02pt100_dirty  \
# 375       634.1            672.1           614.7                 619.0
# 376       631.2            671.1           613.5                 618.0
# ...

# %%
    df2 = df2.fillna('-9999')

# %%
df2.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630      17.6    405.0       695.1       717.8
# 376  2017-12-13 14:38:56  506631      17.6    405.0       693.9       716.3
# 377  2017-12-13 14:38:57  506632      17.5    405.1       693.2       715.3
# 378  2017-12-13 14:38:58  506633      17.5    405.1       692.8       714.6
#
#      GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# 375       713.9      726.6          686.2        675.9         571.0
# 376       712.5      723.5          684.8        675.2         571.0
# 377       712.0      721.1          684.1        674.5         570.0
# 378       711.3      723.0          683.7        673.7         570.0
#
#      DfHIP_SPN1  TGIP_SMP11_VENT TGHIP_SI02pt100 TGHIP_SI02pt100_dirty  \
# 375       634.1            672.1           614.7                 619.0
# 376       631.2            671.1           613.5                 618.0
# ...

# %%
df2[["GHIP_SI02pt100", "TGHIP_SI02pt100","TGHIP_SI02pt100_dirty","wind_speed","wind_direction","DIF_GLO_REF_SPN1"]] = df2[["GHIP_SI02pt100", "TGHIP_SI02pt100","TGHIP_SI02pt100_dirty","wind_speed","wind_direction","DIF_GLO_REF_SPN1"]].astype("float32")

# %%
df2.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float32
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100          float32
# TGHIP_SI02pt100_dirty    float32
# wind_speed               float32
# wind_direction           float32
# DIF_GLO_REF_SPN1         float32
# dtype: object

# %%
df2.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630      17.6    405.0       695.1       717.8
# 376  2017-12-13 14:38:56  506631      17.6    405.0       693.9       716.3
# 377  2017-12-13 14:38:57  506632      17.5    405.1       693.2       715.3
# 378  2017-12-13 14:38:58  506633      17.5    405.1       692.8       714.6
#
#      GHIP_SMP11  GHIP_SPN1  GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# 375       713.9      726.6      686.200012        675.9         571.0
# 376       712.5      723.5      684.799988        675.2         571.0
# 377       712.0      721.1      684.099976        674.5         570.0
# 378       711.3      723.0      683.700012        673.7         570.0
#
#      DfHIP_SPN1  TGIP_SMP11_VENT  TGHIP_SI02pt100  TGHIP_SI02pt100_dirty  \
# 375       634.1            672.1       614.700012             619.000000
# 376       631.2            671.1       613.500000             618.000000
# ...

# %%
df2 = df2.fillna(-9999)

# %%
df2.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float32
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100          float32
# TGHIP_SI02pt100_dirty    float32
# wind_speed               float32
# wind_direction           float32
# DIF_GLO_REF_SPN1         float32
# dtype: object

# %%
df2.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630      17.6    405.0       695.1       717.8
# 376  2017-12-13 14:38:56  506631      17.6    405.0       693.9       716.3
# 377  2017-12-13 14:38:57  506632      17.5    405.1       693.2       715.3
# 378  2017-12-13 14:38:58  506633      17.5    405.1       692.8       714.6
#
#      GHIP_SMP11  GHIP_SPN1  GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# 375       713.9      726.6      686.200012        675.9         571.0
# 376       712.5      723.5      684.799988        675.2         571.0
# 377       712.0      721.1      684.099976        674.5         570.0
# 378       711.3      723.0      683.700012        673.7         570.0
#
#      DfHIP_SPN1  TGIP_SMP11_VENT  TGHIP_SI02pt100  TGHIP_SI02pt100_dirty  \
# 375       634.1            672.1       614.700012             619.000000
# 376       631.2            671.1       613.500000             618.000000
# ...

# %%
df4 = pd.read_csv(datafiles[0], 
                    usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT',
                             'wind_speed', 
                             'wind_direction'],
                      na_values = -9999)

# %%
df4.shape
# Out:
# (3441923, 18)

# %%
df4.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100            object
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100           object
# TGHIP_SI02pt100_dirty     object
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1          object
# dtype: object

# %%
df4.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630      17.6    405.0       695.1       717.8
# 376  2017-12-13 14:38:56  506631      17.6    405.0       693.9       716.3
# 377  2017-12-13 14:38:57  506632      17.5    405.1       693.2       715.3
# 378  2017-12-13 14:38:58  506633      17.5    405.1       692.8       714.6
#
#      GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# 375       713.9      726.6          686.2        675.9         571.0
# 376       712.5      723.5          684.8        675.2         571.0
# 377       712.0      721.1          684.1        674.5         570.0
# 378       711.3      723.0          683.7        673.7         570.0
#
#      DfHIP_SPN1  TGIP_SMP11_VENT TGHIP_SI02pt100 TGHIP_SI02pt100_dirty  \
# 375       634.1            672.1           614.7                 619.0
# 376       631.2            671.1           613.5                 618.0
# ...

# %%
bdf2[["GHIP_SI02pt100", "TGHIP_SI02pt100","TGHIP_SI02pt100_dirty","wind_speed","wind_direction","DIF_GLO_REF_SPN1"]] = df2[["GHIP_SI02pt100", "TGHIP_SI02pt100","TGHIP_SI02pt100_dirty","wind_speed","wind_direction","DIF_GLO_REF_SPN1"]].astype("float32")

# %%
df4
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 0            1047.0      1028.0     1012.0         1019.0        767.0
# ...

# %%
df4.2
# Out:
#   File "<ipython-input-124-809a14e5c60a>", line 1
#     df4.2
#        ^
# SyntaxError: invalid syntax

# %%
df2.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float32
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGHIP_SI02pt100          float32
# TGHIP_SI02pt100_dirty    float32
# wind_speed               float32
# wind_direction           float32
# DIF_GLO_REF_SPN1         float32
# dtype: object

# %%
find = df2[df2['TGHIP_SI02pt100_dirty']== -9999]

# %%
find
# Out:
# Empty DataFrame
# Columns: [TIMESTAMP, RECORD, DNI_SHP1, LW_SGR4, GHIT_SMP22, GHIP_SMP22, GHIP_SMP11, GHIP_SPN1, GHIP_SI02pt100, DfHIT_SMP22, DfHIRP_SMP11, DfHIP_SPN1, TGIP_SMP11_VENT, TGHIP_SI02pt100, TGHIP_SI02pt100_dirty, wind_speed, wind_direction, DIF_GLO_REF_SPN1]
# Index: []

# %%
test =df1.isna()

# %%
df1.shape
# Out:
# (3441923, 18)

# %%
test
# Out:
#          TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  GHIP_SMP22  \
# 0            False   False     False    False       False       False
# 1            False   False     False    False       False       False
# 2            False   False     False    False       False       False
# 3            False   False     False    False       False       False
# 4            False   False     False    False       False       False
# ...            ...     ...       ...      ...         ...         ...
# 3441918      False   False     False    False       False       False
# 3441919      False   False     False    False       False       False
# 3441920      False   False     False    False       False       False
# 3441921      False   False     False    False       False       False
# 3441922      False   False     False    False       False       False
#
#          GHIP_SMP11  GHIP_SPN1  GHIP_SI02pt100  DfHIT_SMP22  DfHIRP_SMP11  \
# ...

# %%
a = test[test['DIF_GLO_REF_SPN1'] == True].index

# %%
a.shape
# Out:
# (0,)

# %%
b = df1[df1['GHIP_SI02pt100'] == -9999].index
b.shape
# Out:
# (0,)

# %%
    df3 = pd.read_csv(datafiles[0], 
                    usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT',
                             'wind_speed', 
                             'wind_direction'
                            ],
                    na_values = -9999,
                    dtype={'TIMESTAMP': str,
                          'RECORD': int, 
                          'DfHIP_SPN1': float, 
                          'DfHIRP_SMP11': float,
                          'DfHIT_SMP22': float,
                          'DIF_GLO_REF_SPN1': float,
                          'DNI_SHP1': float,
                          'GHIP_SI02pt100': float,
                          'GHIP_SMP11': float,
                          'GHIP_SMP22': float,
                          'GHIP_SPN1': float,
                          'GHIT_SMP22': float,
                          'LW_SGR4': float, 
                          'TGHIP_SI02pt100': float, 
                          'TGHIP_SI02pt100_dirty': float,
                          'TGIP_SMP11_VENT': float,
                          'wind_speed': float, 
                          'wind_direction': float,
                          })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-4b5fe62ddff1> in <module>
# ----> 1 df3 = pd.read_csv(datafiles[0],
#       2                 usecols=['TIMESTAMP',
#       3                          'RECORD',
#       4                          'DfHIP_SPN1',
#       5                          'DfHIRP_SMP11',
#
# ...

# %%
df11 = pd.read_csv(datafiles[0], 
                     usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                             'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                             'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                             'TGHIP_SI02pt100', 
                             'TGHIP_SI02pt100_dirty',
                             'TGIP_SMP11_VENT',
                             'wind_speed', 
                             'wind_direction']
                    )[['TIMESTAMP',
                      'RECORD',
                      'GHIP_SI02pt100',
                      'GHIP_SMP11',
                      'GHIP_SMP22',
                      'GHIP_SPN1',
                      'GHIT_SMP22',
                      'TGHIP_SI02pt100', 
                      'TGHIP_SI02pt100_dirty',
                      'TGIP_SMP11_VENT',
                      'DfHIP_SPN1', 
                      'DfHIRP_SMP11',
                      'DfHIT_SMP22',
                      'DIF_GLO_REF_SPN1',
                      'DNI_SHP1',
                      'LW_SGR4', 
                      'wind_speed', 
                      'wind_direction']]   

df11[['GHIP_SI02pt100','GHIP_SMP11','GHIP_SMP22','GHIP_SPN1','GHIT_SMP22',
         'TGHIP_SI02pt100','TGHIP_SI02pt100_dirty','TGIP_SMP11_VENT',
         'DfHIP_SPN1','DfHIRP_SMP11','DfHIT_SMP22','DIF_GLO_REF_SPN1',
         'DNI_SHP1','LW_SGR4', 'wind_speed','wind_direction']] = df11[['GHIP_SI02pt100',
         'GHIP_SMP11','GHIP_SMP22','GHIP_SPN1','GHIT_SMP22','TGHIP_SI02pt100',
         'TGHIP_SI02pt100_dirty','TGIP_SMP11_VENT','DfHIP_SPN1','DfHIRP_SMP11',
         'DfHIT_SMP22','DIF_GLO_REF_SPN1','DNI_SHP1','LW_SGR4', 'wind_speed',
         'wind_direction']].astype("float64")                
df11 = df11.fillna(-9999)
# Out:
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df11.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# GHIP_SI02pt100           float64
# GHIP_SMP11               float64
# GHIP_SMP22               float64
# GHIP_SPN1                float64
# GHIT_SMP22               float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# TGIP_SMP11_VENT          float64
# DfHIP_SPN1               float64
# DfHIRP_SMP11             float64
# DfHIT_SMP22              float64
# DIF_GLO_REF_SPN1         float64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# wind_speed               float64
# wind_direction           float64
# dtype: object

# %%
df11.loc[375:378]
# Out:
#                TIMESTAMP  RECORD  GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 375  2017-12-13 14:38:55  506630           686.2       713.9       717.8
# 376  2017-12-13 14:38:56  506631           684.8       712.5       716.3
# 377  2017-12-13 14:38:57  506632           684.1       712.0       715.3
# 378  2017-12-13 14:38:58  506633           683.7       711.3       714.6
#
#      GHIP_SPN1  GHIT_SMP22  TGHIP_SI02pt100  TGHIP_SI02pt100_dirty  \
# 375      726.6       695.1            614.7                  619.0
# 376      723.5       693.9            613.5                  618.0
# 377      721.1       693.2            612.7                  617.2
# 378      723.0       692.8            612.4                  617.0
#
#      TGIP_SMP11_VENT  DfHIP_SPN1  DfHIRP_SMP11  DfHIT_SMP22  DIF_GLO_REF_SPN1  \
# 375            672.1       634.1         571.0        675.9            -40.40
# 376            671.1       631.2         571.0        675.2            -38.63
# ...

# %%
    df11['TIMESTAMP'] = df11['TIMESTAMP'].astype(np.datetime64)

# %%
df11['TIMESTAMP']
# Out:
# 0         2017-12-13 14:32:40
# 1         2017-12-13 14:32:41
# 2         2017-12-13 14:32:42
# 3         2017-12-13 14:32:43
# 4         2017-12-13 14:32:44
#                   ...
# 3441918   2018-01-17 18:57:02
# 3441919   2018-01-17 18:57:03
# 3441920   2018-01-17 18:57:04
# 3441921   2018-01-17 18:57:05
# 3441922   2018-01-17 18:57:06
# Name: TIMESTAMP, Length: 3441923, dtype: datetime64[ns]

# %%
df11.dtypes
# Out:
# TIMESTAMP                datetime64[ns]
# RECORD                            int64
# GHIP_SI02pt100                  float64
# GHIP_SMP11                      float64
# GHIP_SMP22                      float64
# GHIP_SPN1                       float64
# GHIT_SMP22                      float64
# TGHIP_SI02pt100                 float64
# TGHIP_SI02pt100_dirty           float64
# TGIP_SMP11_VENT                 float64
# DfHIP_SPN1                      float64
# DfHIRP_SMP11                    float64
# DfHIT_SMP22                     float64
# DIF_GLO_REF_SPN1                float64
# DNI_SHP1                        float64
# LW_SGR4                         float64
# wind_speed                      float64
# wind_direction                  float64
# dtype: object

# %%
import pvlib

# %%
tus = Location(-27.43
               0891, -48.441406, 'Etc/GMT', 'Florianopolis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-fb7ac89221fe> in <module>
# ----> 1 tus = Location(-27.430891, -48.441406, 'Etc/GMT', 'Florianopolis')
#
# NameError: name 'Location' is not defined

# %%
import datetime
import pytz

# %%
pytz.country_timezones('Brasil')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-69884bb6f9cf> in <module>
# ----> 1 pytz.country_timezones('Brasil')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pytz/__init__.py in __call__(self, iso3166_code)
#     345     def __call__(self, iso3166_code):
#     346         """Backwards compatibility."""
# --> 347         return self[iso3166_code]
#     348
#     349     def _fill(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pytz/lazy.py in __getitem__(self, key)
#      26             finally:
#      27                 _fill_lock.release()
# ---> 28         return self.data[key.upper()]
#      29
#      30     def __contains__(self, key):
#
# KeyError: 'BRASIL'

# %%
pytz.all_timezones[::20]
# Out:
# ['Africa/Abidjan',
#  'Africa/Douala',
#  'Africa/Mbabane',
#  'America/Argentina/Catamarca',
#  'America/Belize',
#  'America/Curacao',
#  'America/Guatemala',
#  'America/Kentucky/Louisville',
#  'America/Mexico_City',
#  'America/Phoenix',
#  'America/Shiprock',
#  'America/Yellowknife',
#  'Asia/Ashgabat',
#  'Asia/Dili',
#  'Asia/Katmandu',
#  'Asia/Pyongyang',
#  'Asia/Tokyo',
#  'Atlantic/Madeira',
#  'Australia/Perth',
#  'Canada/Saskatchewan',
#  'Etc/GMT+6',
#  'Etc/Greenwich',
#  'Europe/Gibraltar',
#  'Europe/Oslo',
#  'Europe/Vatican',
#  'Indian/Christmas',
#  'Mexico/General',
#  'Pacific/Guam',
#  'Pacific/Saipan',
#  'US/East-Indiana']

# %%
df11.TIMESTAMP.loc[1:300]
# Out:
# 1     2017-12-13 14:32:41
# 2     2017-12-13 14:32:42
# 3     2017-12-13 14:32:43
# 4     2017-12-13 14:32:44
# 5     2017-12-13 14:32:45
#               ...
# 296   2017-12-13 14:37:36
# 297   2017-12-13 14:37:37
# 298   2017-12-13 14:37:38
# 299   2017-12-13 14:37:39
# 300   2017-12-13 14:37:40
# Name: TIMESTAMP, Length: 300, dtype: datetime64[ns]

# %%
pd.Timestamp(df11['TIMESTAMP']).tz_localize('Brazil/East')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-f72b3bc9fb76> in <module>
# ----> 1 pd.Timestamp(df11['TIMESTAMP']).tz_localize('Brazil/East')
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# TypeError: Cannot convert input [0         2017-12-13 14:32:40
# 1         2017-12-13 14:32:41
# 2         2017-12-13 14:32:42
# 3         2017-12-13 14:32:43
# 4         2017-12-13 14:32:44
#                   ...
# 3441918   2018-01-17 18:57:02
# 3441919   2018-01-17 18:57:03
# 3441920   2018-01-17 18:57:04
# 3441921   2018-01-17 18:57:05
# 3441922   2018-01-17 18:57:06
# Name: TIMESTAMP, Length: 3441923, dtype: datetime64[ns]] of type <class 'pandas.core.series.Series'> to Timestamp

# %%
timesFLP = df11['TIMESTAMP'].loc[1:10].tz_localize('Etc/GMT+7')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-7de1e90d1014> in <module>
# ----> 1 timesFLP = df11['TIMESTAMP'].loc[1:10].tz_localize('Etc/GMT+7')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in tz_localize(self, tz, axis, level, copy, ambiguous, nonexistent)
#    9944             if level not in (None, 0, ax.name):
#    9945                 raise ValueError(f"The level {level} is not valid")
# -> 9946             ax = _tz_localize(ax, tz, ambiguous, nonexistent)
#    9947
#    9948         result = self.copy(deep=copy)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _tz_localize(ax, tz, ambiguous, nonexistent)
#    9926                 if len(ax) > 0:
#    9927                     ax_name = self._get_axis_name(axis)
# -> 9928                     raise TypeError(
# ...

# %%
naive_times = pd.date_range(start='2015', end='2016', freq='1h')
naive_times.dtype
# Out:
# dtype('<M8[ns]')

# %%
df11['TIMESTAMP']
# Out:
# 0         2017-12-13 14:32:40
# 1         2017-12-13 14:32:41
# 2         2017-12-13 14:32:42
# 3         2017-12-13 14:32:43
# 4         2017-12-13 14:32:44
#                   ...
# 3441918   2018-01-17 18:57:02
# 3441919   2018-01-17 18:57:03
# 3441920   2018-01-17 18:57:04
# 3441921   2018-01-17 18:57:05
# 3441922   2018-01-17 18:57:06
# Name: TIMESTAMP, Length: 3441923, dtype: datetime64[ns]

# %%
timezone = 'Brazil/East'

# %% [markdown]
# times = naive_times.tz_localize('Etc/GMT-3')
#
#
# times

# %%
t = pd.Timestamp('2020-12-1 00:00').tz_localize(timezone)

# %%
t
# Out:
# Timestamp('2020-12-01 00:00:00-0300', tz='Brazil/East')

# %%
file_duration = pd.DataFrame(index = datafiles , columns = ['start','end'])

# %%
file_duration.at[datafiles[0],'start']=df11.iloc[0,0]

# %%
df11.iloc[0,0]
# Out:
# Timestamp('2017-12-13 14:32:40')

# %%
file_duration
# Out:
#                                                                   start  end
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...  2017-12-13 14:32:40  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN  NaN

# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-012ab3a6b187> in <module>
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
df11.iloc[-1,0]
# Out:
# Timestamp('2018-01-17 18:57:06')

# %%
file_duration.at[datafiles[0],'end']= df11.iloc[-1,0]

# %%
file_duration
# Out:
#                                                                   start  \
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...  2017-12-13 14:32:40
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
#
#                                                                     end
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...  2018-01-17 18:57:06
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...                  NaN
# ...

# %%
df11
# Out:
#                   TIMESTAMP  RECORD  GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 0       2017-12-13 14:32:40  506255          1019.0      1028.0      1047.0
# 1       2017-12-13 14:32:41  506256          1023.0      1037.0      1045.0
# 2       2017-12-13 14:32:42  506257          1073.0      1090.0      1086.0
# 3       2017-12-13 14:32:43  506258          1131.0      1159.0      1146.0
# 4       2017-12-13 14:32:44  506259          1236.0      1272.0      1248.0
# ...                     ...     ...             ...         ...         ...
# 3441918 2018-01-17 18:57:02   94538           823.0       893.0       877.0
# 3441919 2018-01-17 18:57:03   94539           851.0       855.0       886.0
# 3441920 2018-01-17 18:57:04   94540           807.0       802.0       857.0
# 3441921 2018-01-17 18:57:05   94541           736.1       742.2       821.0
# 3441922 2018-01-17 18:57:06   94542           686.9       720.4       776.7
#
# ...

# %%
df11.shape
# Out:
# (3441923, 18)

# %%
df2
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1  GHIP_SI02pt100  DfHIT_SMP22  \
# 0            1047.0      1028.0     1012.0     1019.000000        767.0
# ...

# %%
df1
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 0            1047.0      1028.0     1012.0         1019.0        767.0
# ...

# %%
column_names = ['TIMESTAMP',
                'RECORD',
                'GHIP_SI02pt100',
                'GHIP_SMP11',
                'GHIP_SMP22',
                'GHIP_SPN1',
                'GHIT_SMP22',
                'TGHIP_SI02pt100', 
                'TGHIP_SI02pt100_dirty',
                'TGIP_SMP11_VENT',
                'DfHIP_SPN1', 
                'DfHIRP_SMP11',
                'DfHIT_SMP22',
                'DIF_GLO_REF_SPN1',
                'DNI_SHP1',
                'LW_SGR4', 
                'wind_speed', 
                'wind_direction']

# %%
todos = pd.DataFrame(columns = column_names)

# %%
todos.dtypes
# Out:
# TIMESTAMP                object
# RECORD                   object
# GHIP_SI02pt100           object
# GHIP_SMP11               object
# GHIP_SMP22               object
# GHIP_SPN1                object
# GHIT_SMP22               object
# TGHIP_SI02pt100          object
# TGHIP_SI02pt100_dirty    object
# TGIP_SMP11_VENT          object
# DfHIP_SPN1               object
# DfHIRP_SMP11             object
# DfHIT_SMP22              object
# DIF_GLO_REF_SPN1         object
# DNI_SHP1                 object
# LW_SGR4                  object
# wind_speed               object
# wind_direction           object
# dtype: object

# %%
todos
# Out:
# Empty DataFrame
# Columns: [TIMESTAMP, RECORD, GHIP_SI02pt100, GHIP_SMP11, GHIP_SMP22, GHIP_SPN1, GHIT_SMP22, TGHIP_SI02pt100, TGHIP_SI02pt100_dirty, TGIP_SMP11_VENT, DfHIP_SPN1, DfHIRP_SMP11, DfHIT_SMP22, DIF_GLO_REF_SPN1, DNI_SHP1, LW_SGR4, wind_speed, wind_direction]
# Index: []

# %%
todos = pd.concat([todos, df1])

# %%
todos.dtypes
# Out:
# TIMESTAMP                datetime64[ns]
# RECORD                           object
# GHIP_SI02pt100                  float64
# GHIP_SMP11                      float64
# GHIP_SMP22                      float64
# GHIP_SPN1                       float64
# GHIT_SMP22                      float64
# TGHIP_SI02pt100                 float64
# TGHIP_SI02pt100_dirty           float64
# TGIP_SMP11_VENT                 float64
# DfHIP_SPN1                      float64
# DfHIRP_SMP11                    float64
# DfHIT_SMP22                     float64
# DIF_GLO_REF_SPN1                float64
# DNI_SHP1                        float64
# LW_SGR4                         float64
# wind_speed                      float64
# wind_direction                  float64
# dtype: object

# %%
df11.dtypes
# Out:
# TIMESTAMP                datetime64[ns]
# RECORD                            int64
# GHIP_SI02pt100                  float64
# GHIP_SMP11                      float64
# GHIP_SMP22                      float64
# GHIP_SPN1                       float64
# GHIT_SMP22                      float64
# TGHIP_SI02pt100                 float64
# TGHIP_SI02pt100_dirty           float64
# TGIP_SMP11_VENT                 float64
# DfHIP_SPN1                      float64
# DfHIRP_SMP11                    float64
# DfHIT_SMP22                     float64
# DIF_GLO_REF_SPN1                float64
# DNI_SHP1                        float64
# LW_SGR4                         float64
# wind_speed                      float64
# wind_direction                  float64
# dtype: object

# %%
todos
# Out:
#                   TIMESTAMP  RECORD  GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 0       2017-12-13 14:32:40  506255          1019.0      1028.0      1047.0
# 1       2017-12-13 14:32:41  506256          1023.0      1037.0      1045.0
# 2       2017-12-13 14:32:42  506257          1073.0      1090.0      1086.0
# 3       2017-12-13 14:32:43  506258          1131.0      1159.0      1146.0
# 4       2017-12-13 14:32:44  506259          1236.0      1272.0      1248.0
# ...                     ...     ...             ...         ...         ...
# 3441918 2018-01-17 18:57:02   94538           823.0       893.0       877.0
# 3441919 2018-01-17 18:57:03   94539           851.0       855.0       886.0
# 3441920 2018-01-17 18:57:04   94540           807.0       802.0       857.0
# 3441921 2018-01-17 18:57:05   94541           736.1       742.2       821.0
# 3441922 2018-01-17 18:57:06   94542           686.9       720.4       776.7
#
# ...

# %%
todos
# Out:
#                    TIMESTAMP  RECORD GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 0        2017-12-13 14:32:40  506255         1019.0      1028.0      1047.0
# 1        2017-12-13 14:32:41  506256         1023.0      1037.0      1045.0
# 2        2017-12-13 14:32:42  506257         1073.0      1090.0      1086.0
# 3        2017-12-13 14:32:43  506258         1131.0      1159.0      1146.0
# 4        2017-12-13 14:32:44  506259         1236.0      1272.0      1248.0
# ...                      ...     ...            ...         ...         ...
# 3441918  2018-01-17 18:57:02   94538          823.0       893.0       877.0
# 3441919  2018-01-17 18:57:03   94539          851.0       855.0       886.0
# 3441920  2018-01-17 18:57:04   94540          807.0       802.0       857.0
# 3441921  2018-01-17 18:57:05   94541          736.1       742.2       821.0
# 3441922  2018-01-17 18:57:06   94542          686.9       720.4       776.7
#
# ...

# %%
semtodos = todos.drop_duplicates(subset='TIMESTAMP')

# %%
semtodos
# Out:
#                    TIMESTAMP  RECORD GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 0        2017-12-13 14:32:40  506255         1019.0      1028.0      1047.0
# 1        2017-12-13 14:32:41  506256         1023.0      1037.0      1045.0
# 2        2017-12-13 14:32:42  506257         1073.0      1090.0      1086.0
# 3        2017-12-13 14:32:43  506258         1131.0      1159.0      1146.0
# 4        2017-12-13 14:32:44  506259         1236.0      1272.0      1248.0
# ...                      ...     ...            ...         ...         ...
# 3382850  2018-01-18 12:29:58  157691          792.9       822.0       824.0
# 3382851  2018-01-18 12:29:59  157692          791.8       821.0       823.0
# 3382852  2018-01-18 12:30:00  157693          790.4       820.0       822.0
# 3382853  2018-01-18 12:30:01  157694          789.5       819.0       821.0
# 3382854  2018-01-18 12:30:02  157695          788.1       818.0       819.0
#
# ...

# %%
todos.tail()
# Out:
#                    TIMESTAMP RECORD GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 3441918  2018-01-17 18:57:02  94538          823.0       893.0       877.0
# 3441919  2018-01-17 18:57:03  94539          851.0       855.0       886.0
# 3441920  2018-01-17 18:57:04  94540          807.0       802.0       857.0
# 3441921  2018-01-17 18:57:05  94541          736.1       742.2       821.0
# 3441922  2018-01-17 18:57:06  94542          686.9       720.4       776.7
#
#          GHIP_SPN1  GHIT_SMP22 TGHIP_SI02pt100 TGHIP_SI02pt100_dirty  \
# 3441918      823.0       883.0           679.1                 706.6
# 3441919      816.0       883.0           690.0                 700.9
# 3441920      759.9       846.0           645.8                 653.7
# 3441921      702.4       803.0           588.7                 606.4
# 3441922      657.7       755.4           553.6                 566.6
#
#          TGIP_SMP11_VENT  DfHIP_SPN1  DfHIRP_SMP11  DfHIT_SMP22  \
# ...

# %%
semtodos.tail(5)
# Out:
#                    TIMESTAMP  RECORD GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  \
# 3382850  2018-01-18 12:29:58  157691          792.9       822.0       824.0
# 3382851  2018-01-18 12:29:59  157692          791.8       821.0       823.0
# 3382852  2018-01-18 12:30:00  157693          790.4       820.0       822.0
# 3382853  2018-01-18 12:30:01  157694          789.5       819.0       821.0
# 3382854  2018-01-18 12:30:02  157695          788.1       818.0       819.0
#
#          GHIP_SPN1  GHIT_SMP22 TGHIP_SI02pt100 TGHIP_SI02pt100_dirty  \
# 3382850      789.0       826.0           675.8                 687.5
# 3382851      787.7       825.0           674.9                 686.9
# 3382852      785.2       824.0           673.5                 685.6
# 3382853      784.1       823.0           673.1                 684.8
# 3382854      784.4       822.0           671.6                 683.0
#
#          TGIP_SMP11_VENT  DfHIP_SPN1  DfHIRP_SMP11  DfHIT_SMP22  \
# ...

# %%
df1.tail(10)
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 3441913  2018-01-17 18:56:57   94533     211.4    420.9       453.9
# 3441914  2018-01-17 18:56:58   94534     231.1    420.9       470.0
# 3441915  2018-01-17 18:56:59   94535     294.3    420.9       545.6
# 3441916  2018-01-17 18:57:00   94536     549.4    420.9       713.8
# 3441917  2018-01-17 18:57:01   94537     783.1    421.0       835.0
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 3441913       457.5       471.1      438.0          445.9        310.3
# 3441914       468.1       529.9      469.5          470.3        311.2
# ...

# %%
df1uniq = df1.drop_duplicates(subset='TIMESTAMP')

# %%
df1.tail(10)
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 3441913  2018-01-17 18:56:57   94533     211.4    420.9       453.9
# 3441914  2018-01-17 18:56:58   94534     231.1    420.9       470.0
# 3441915  2018-01-17 18:56:59   94535     294.3    420.9       545.6
# 3441916  2018-01-17 18:57:00   94536     549.4    420.9       713.8
# 3441917  2018-01-17 18:57:01   94537     783.1    421.0       835.0
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1 GHIP_SI02pt100  DfHIT_SMP22  \
# 3441913       457.5       471.1      438.0          445.9        310.3
# 3441914       468.1       529.9      469.5          470.3        311.2
# ...

# %%
naive_times = pd.date_range(start='2017-12-13 14:32:40', end='2018-01-18 12:30:02', freq='1s')

# %%
naive_times.shape
# Out:
# (3103043,)

# %%
naive_times
# Out:
# DatetimeIndex(['2017-12-13 14:32:40', '2017-12-13 14:32:41',
#                '2017-12-13 14:32:42', '2017-12-13 14:32:43',
#                '2017-12-13 14:32:44', '2017-12-13 14:32:45',
#                '2017-12-13 14:32:46', '2017-12-13 14:32:47',
#                '2017-12-13 14:32:48', '2017-12-13 14:32:49',
#                ...
#                '2018-01-18 12:29:53', '2018-01-18 12:29:54',
#                '2018-01-18 12:29:55', '2018-01-18 12:29:56',
#                '2018-01-18 12:29:57', '2018-01-18 12:29:58',
#                '2018-01-18 12:29:59', '2018-01-18 12:30:00',
#                '2018-01-18 12:30:01', '2018-01-18 12:30:02'],
#               dtype='datetime64[ns]', length=3103043, freq='S')
