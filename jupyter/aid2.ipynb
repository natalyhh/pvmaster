# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
PATH18 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/*.dat"

# %%
datafiles = glob.glob(PATH18)
datafiles.sort()

file1 = datafiles[0]
dataref = pd.read_csv(file1)  

filetest = pd.DataFrame(index = dataref.columns , columns = datafiles)
# Out:
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,9,10,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
filetest
# Out:
#                       /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat  \
# TIMESTAMP                                                            NaN
# RECORD                                                               NaN
# DNI_SHP1                                                             NaN
# LW_SGR4                                                              NaN
# GHIT_SMP22                                                           NaN
# GHIP_SMP22                                                           NaN
# GHIP_SMP11                                                           NaN
# GHIP_SPN1                                                            NaN
# GHIP_SI02pt100                                                       NaN
# UV                                                                   NaN
# Par                                                                  NaN
# ...

# %%
filetest.shape
# Out:
# (23, 8)

# %%
datafiles
# Out:
# ['/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_2.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_3.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_4.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_5.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_6.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_7.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_8.dat']

# %%
for path in datafiles:
    df = pd.read_csv(path)
    teste = dataref.columns == df.columns
    filetest[path] = teste
    print(filetest)
# Out:
#                        /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat  \
# TIMESTAMP                                                           True
# RECORD                                                              True
# DNI_SHP1                                                            True
# LW_SGR4                                                             True
# GHIT_SMP22                                                          True
# GHIP_SMP22                                                          True
# GHIP_SMP11                                                          True
# GHIP_SPN1                                                           True
# GHIP_SI02pt100                                                      True
# UV                                                                  True
# Par                                                                 True
# ...

# %%
filetest
# Out:
#                        /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat  \
# TIMESTAMP                                                           True
# RECORD                                                              True
# DNI_SHP1                                                            True
# LW_SGR4                                                             True
# GHIT_SMP22                                                          True
# GHIP_SMP22                                                          True
# GHIP_SMP11                                                          True
# GHIP_SPN1                                                           True
# GHIP_SI02pt100                                                      True
# UV                                                                  True
# Par                                                                 True
# ...

# %%
filetestt = filetest.T

# %%
filetestt
# Out:
#                                                     TIMESTAMP  RECORD  \
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...       True    True
#
#                                                     DNI_SHP1  LW_SGR4  \
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...      True     True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...      True     True
# /Users/nataly/opt/AnacondaProjects/SAPIENS/orig...      True     True
# ...

# %%
filetestt.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'GHIP_SI02pt100', 'UV', 'Par',
#        'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGIP_SMP11_NoVen', 'TGIP_SMP6_NoVen', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTime'],
#       dtype='object')

# %%
PATH17 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/*.dat"

# %%
datafiles17 = glob.glob(PATH17)
datafiles17.sort()

# %%
datafiles17
# Out:
# ['/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_01.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_02.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_03.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_04.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_05.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_06.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_07.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_08.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_09.dat',
# ...

# %%
filetest17 = pd.DataFrame(index = dataref.columns , columns = datafiles17)

# %%
filetest17.shape
# Out:
# (23, 12)

# %%
for path in datafiles17:
    df = pd.read_csv(path)
    print(path)
    print(df.shape)
    print(df.columns)
# Out:
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_01.dat
# (668547, 9)
# Index(['TIMESTAMP', 'RECORD', 'UV', 'Par', 'wind_speed', 'wind_direction',
#        'GHIP_SI02pt100', 'TGHIP_SI02pt100', 'TGHIP_SI02pt100_dirty'],
#       dtype='object')
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4,5,8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_02.dat
# (1279621, 11)
# Index(['TIMESTAMP', 'RECORD', 'UV', 'Par', 'GHIP_SPN1', 'DfHIP_SPN1',
#        'wind_speed', 'wind_direction', 'GHIP_SI02pt100', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty'],
#       dtype='object')
# ...

# %%
datafiles17
# Out:
# ['/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_01.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_02.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_03.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_04.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_05.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_06.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_07.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_08.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2017/CR3000/Sec/SAPIENS_CR3000_Second_09.dat',
# ...

# %%
PATH19 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2019/CR3000/Sec/*.dat"

# %%
datafiles19 = glob.glob(PATH19)
datafiles19.sort()

for path in datafiles19:
    df = pd.read_csv(path)
    print(path)
    print(df.shape)
    print(df.columns)
# Out:
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2019/CR3000/Sec/SAPIENS_CR3000_Second_01.dat
# (2508090, 23)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'GHIP_SI02pt100', 'UV', 'Par',
#        'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGIP_SMP11', 'TGIP11__SMP6', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTimeTudo'],
#       dtype='object')
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,9,10,17,18,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2019/CR3000/Sec/SAPIENS_CR3000_Second_02.dat
# (417195, 23)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
# ...

# %%
PATH20 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2020/CR3000/Sec/*.dat"
datafiles20 = glob.glob(PATH20)
datafiles20.sort()

for path in datafiles20:
    df = pd.read_csv(path)
    print(path)
    print(df.shape)
    print(df.columns)
# Out:
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2020/CR3000/Sec/SAPIENS_CR3000_Second_1.dat
# (1951348, 23)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_MS80', 'GHIP_SR20', 'GHIP_SPN1',
#        'GHIP_SI02pt100', 'UV', 'Par', 'DfHIT_SMP22', 'DfHIRP_SMP11',
#        'DfHIP_SPN1', 'TGIP_SMP11_VENT', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTimeTudo'],
#       dtype='object')
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2020/CR3000/Sec/SAPIENS_CR3000_Second_2.dat
# (4032098, 24)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_MS80', 'GHIP_SR20', 'GHIP_SPN1',
#        'GHIP_SI02pt100', 'TGHIP_SI02pt100_dirty', 'TGHIP12_SI02pt1000', 'UV',
#        'Par', 'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
# ...

# %%
PATH21 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2021/CR3000/Sec/*.dat"
datafiles21 = glob.glob(PATH21)
datafiles21.sort()

for path in datafiles21:
    df = pd.read_csv(path)
    print(path)
    print(df.shape)
    print(df.columns)
# Out:
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2021/CR3000/Sec/SAPIENS_CR3000_Second_1.dat
# (1780224, 24)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_MS80', 'GHIP_SR20', 'GHIP_SPN1',
#        'GHIP_SI02pt100', 'TGHIP_SI02pt100_dirty', 'TGHIP12_SI02pt1000', 'UV',
#        'Par', 'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGHIP_SI02pt100', 'wind_speed', 'wind_direction', 'DIF_GLO_REF_SPN1',
#        'ElapsedTimeTudo'],
#       dtype='object')

# %%
PATH18 = "/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/*.dat"
datafiles18 = glob.glob(PATH18)
datafiles18.sort()

for path in datafiles18:
    df = pd.read_csv(path)
    print(path)
    print(df.shape)
    print(df.columns)
# Out:
# /Users/nataly/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,9,10,17,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat
# (3441923, 23)
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'GHIP_SI02pt100', 'UV', 'Par',
#        'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGIP_SMP11_NoVen', 'TGIP_SMP6_NoVen', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTime'],
#       dtype='object')
# /Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_2.dat
# (595217, 23)
# ...

# %% [markdown]
# datafiles

# %%
datafiles
# Out:
# ['/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_2.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_3.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_4.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_5.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_6.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_7.dat',
#  '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_8.dat']

# %%
datafiles[0]
# Out:
# '/Users/nataly/opt/AnacondaProjects/SAPIENS/original/2018/CR3000/Sec/SAPIENS_CR3000_Second_1.dat'

# %%
df1 = pd.read_csv(datafiles[0])

# %%
df2 = pd.read_csv(datafiles[1])

# %%
df1.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'GHIP_SI02pt100', 'UV', 'Par',
#        'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGIP_SMP11_NoVen', 'TGIP_SMP6_NoVen', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTime'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'GHIP_SI02pt100', 'UV', 'Par',
#        'DfHIT_SMP22', 'DfHIRP_SMP11', 'DfHIP_SPN1', 'TGIP_SMP11_VENT',
#        'TGIP_SMP11_NoVen', 'TGIP_SMP6_NoVen', 'TGHIP_SI02pt100',
#        'TGHIP_SI02pt100_dirty', 'wind_speed', 'wind_direction',
#        'DIF_GLO_REF_SPN1', 'ElapsedTime'],
#       dtype='object')

# %%
c = {'TIMESTAMP', 'RECORD', 'DfHIP_SPN1', 'DfHIRP_SMP11','DfHIT_SMP22','DIF_GLO_REF_SPN1','DNI_SHP1','GHIP_SI02pt100','GHIP_SMP11','GHIP_SMP22','GHIP_SPN1','GHIT_SMP22','LW_SGR4', 'TGHIP_SI02pt100', 'TGHIP_SI02pt100_dirty','TGIP_SMP11_VENT','wind_speed', 'wind_direction','ElapsedTime'}

# %%
c
# Out:
# {'DIF_GLO_REF_SPN1',
#  'DNI_SHP1',
#  'DfHIP_SPN1',
#  'DfHIRP_SMP11',
#  'DfHIT_SMP22',
#  'ElapsedTime',
#  'GHIP_SI02pt100',
#  'GHIP_SMP11',
#  'GHIP_SMP22',
#  'GHIP_SPN1',
#  'GHIT_SMP22',
#  'LW_SGR4',
#  'RECORD',
#  'TGHIP_SI02pt100',
#  'TGHIP_SI02pt100_dirty',
#  'TGIP_SMP11_VENT',
#  'TIMESTAMP',
#  'wind_direction',
#  'wind_speed'}

# %%
import matplotlib.pyplot as plt

# %%
df1.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100            object
# UV                        object
# Par                       object
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100           object
# TGHIP_SI02pt100_dirty     object
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1          object
# ElapsedTime                int64
# dtype: object

# %%
 df1 = pd.read_csv(datafiles[0], 
                    usecols=['TIMESTAMP',
                             'RECORD',
                             'DfHIP_SPN1', 
                             'DfHIRP_SMP11',
                             'DfHIT_SMP22',
                           # 'DIF_GLO_REF_SPN1',
                             'DNI_SHP1',
                           # 'GHIP_SI02pt100',
                             'GHIP_SMP11',
                             'GHIP_SMP22',
                             'GHIP_SPN1',
                             'GHIT_SMP22',
                             'LW_SGR4', 
                           # 'TGHIP_SI02pt100', 
                           # 'TGHIP_SI02pt100_dirty',
                            'TGIP_SMP11_VENT',
                           #  'wind_speed', 
                           #  'wind_direction',
                            ],
                    dtype={'TIMESTAMP': str,
                          'RECORD': int, 
                          'DfHIP_SPN1': float, 
                          'DfHIRP_SMP11': float,
                          'DfHIT_SMP22': float,
                        #'DIF_GLO_REF_SPN1': float,
                          'DNI_SHP1': float,
                        # 'GHIP_SI02pt100': float,
                          'GHIP_SMP11': float,
                          'GHIP_SMP22': float,
                          'GHIP_SPN1': float,
                          'GHIT_SMP22': float,
                          'LW_SGR4': float, 
                        # 'TGHIP_SI02pt100': float, 
                        # 'TGHIP_SI02pt100_dirty': float,
                          'TGIP_SMP11_VENT': float,
                        #  'wind_speed': float, 
                        #  'wind_direction': float,
                          })

# %%
df1.dtypes
# Out:
# TIMESTAMP           object
# RECORD               int64
# DNI_SHP1           float64
# LW_SGR4            float64
# GHIT_SMP22         float64
# GHIP_SMP22         float64
# GHIP_SMP11         float64
# GHIP_SPN1          float64
# DfHIT_SMP22        float64
# DfHIRP_SMP11       float64
# DfHIP_SPN1         float64
# TGIP_SMP11_VENT    float64
# ElapsedTime          int64
# dtype: object

# %%
df1.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'DNI_SHP1', 'LW_SGR4', 'GHIT_SMP22',
#        'GHIP_SMP22', 'GHIP_SMP11', 'GHIP_SPN1', 'DfHIT_SMP22', 'DfHIRP_SMP11',
#        'DfHIP_SPN1'],
#       dtype='object')

# %%
bix = pd.read_csv(datafiles[0], 
                    usecols=[ 'DIF_GLO_REF_SPN1',
                              'GHIP_SI02pt100',
                            'TGHIP_SI02pt100', 
                            'TGHIP_SI02pt100_dirty',
                             'wind_speed', 
                             'wind_direction',                   
                            ])

# %%
bix
# Out:
#         GHIP_SI02pt100 TGHIP_SI02pt100 TGHIP_SI02pt100_dirty wind_speed  \
# 0               1019.0           907.0                 910.0       1.14
# 1               1023.0           906.0                 917.0        1.3
# 2               1073.0           950.0                 967.0       1.18
# 3               1131.0          1005.0                1027.0       0.96
# 4               1236.0          1100.0                1131.0       0.91
# ...                ...             ...                   ...        ...
# 3441918          823.0           679.1                 706.6       2.47
# 3441919          851.0           690.0                 700.9       2.07
# 3441920          807.0           645.8                 653.7        1.5
# 3441921          736.1           588.7                 606.4       1.57
# 3441922          686.9           553.6                 566.6       1.98
#
#         wind_direction DIF_GLO_REF_SPN1
# 0                   35            7.071
# ...

# %%
bix.dtypes
# Out:
# GHIP_SI02pt100           object
# TGHIP_SI02pt100          object
# TGHIP_SI02pt100_dirty    object
# wind_speed               object
# wind_direction           object
# DIF_GLO_REF_SPN1         object
# dtype: object

# %%
bix = bix.fillna('-9999')
bix = pd.to_numeric(bix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-e73fb1196844> in <module>
#       1 bix = bix.fillna('-9999')
# ----> 2 bix = pd.to_numeric(bix)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     139         values = np.array([arg], dtype="O")
#     140     elif getattr(arg, "ndim", 1) > 1:
# --> 141         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     142     else:
#     143         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
bixx = bix.apply(pd.to_numeric, errors="ignore")

# %%
bixx.dtypes
# Out:
# GHIP_SI02pt100           object
# TGHIP_SI02pt100          object
# TGHIP_SI02pt100_dirty    object
# wind_speed               object
# wind_direction           object
# DIF_GLO_REF_SPN1         object
# dtype: object

# %%
df2.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float64
# UV                       float64
# Par                      float64
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1         float64
# ElapsedTime                int64
# dtype: object

# %%
df22 = df2.apply(pd.to_numeric, errors="ignore")

# %%
df22.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float64
# UV                       float64
# Par                      float64
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1         float64
# ElapsedTime                int64
# dtype: object

# %%
df1
# Out:
#                    TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0        2017-12-13 14:32:40  506255     240.1    404.5      1028.0
# 1        2017-12-13 14:32:41  506256     252.8    404.7      1045.0
# 2        2017-12-13 14:32:42  506257     307.6    404.8      1095.0
# 3        2017-12-13 14:32:43  506258     378.0    404.9      1160.0
# 4        2017-12-13 14:32:44  506259     485.8    405.0      1260.0
# ...                      ...     ...       ...      ...         ...
# 3441918  2018-01-17 18:57:02   94538     879.0    421.0       883.0
# 3441919  2018-01-17 18:57:03   94539     889.0    421.1       883.0
# 3441920  2018-01-17 18:57:04   94540     825.0    421.1       846.0
# 3441921  2018-01-17 18:57:05   94541     748.2    421.2       803.0
# 3441922  2018-01-17 18:57:06   94542     660.8    421.2       755.4
#
#          GHIP_SMP22  GHIP_SMP11  GHIP_SPN1  DfHIT_SMP22  DfHIRP_SMP11  \
# 0            1047.0      1028.0     1012.0        767.0         617.0
# ...

# %%
df1['ElapsedTime'].plot()
# Out:
# <AxesSubplot:>

# %%
par = df1['Par']

# %%
par
# Out:
# 0          2186.0
# 1          2210.0
# 2          2323.0
# 3          2455.0
# 4          2683.0
#             ...
# 3441918    1877.0
# 3441919    1876.0
# 3441920    1772.0
# 3441921    1654.0
# 3441922    1535.0
# Name: Par, Length: 3441923, dtype: object

# %%
par.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-2e263c08d1e1> in <module>
# ----> 1 par.plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     276     def generate(self):
# ...

# %%
df2
# Out:
#                   TIMESTAMP  RECORD  DNI_SHP1  LW_SGR4  GHIT_SMP22  \
# 0       2018-01-17 14:58:22   80247      43.9    434.2       725.2
# 1       2018-01-17 14:58:23   80248      45.0    434.1       726.6
# 2       2018-01-17 14:58:24   80249      46.6    434.0       728.3
# 3       2018-01-17 14:58:25   80250      47.6    433.8       729.7
# 4       2018-01-17 14:58:26   80251      49.0    433.6       731.2
# ...                     ...     ...       ...      ...         ...
# 595212  2018-01-23 15:46:16  597511     326.5    423.5       760.0
# 595213  2018-01-23 15:46:17  597512     325.7    423.5       759.4
# 595214  2018-01-23 15:46:18  597513     322.8    423.5       757.1
# 595215  2018-01-23 15:46:20  597514     321.7    423.5       756.4
# 595216  2018-01-23 15:46:21  597515     321.8    423.5       756.6
#
#         GHIP_SMP22  GHIP_SMP11  GHIP_SPN1  GHIP_SI02pt100     UV  ...  \
# 0            748.4       749.3      726.6           733.8  46.24  ...
# ...

# %%
df3 = pd.read_csv(datafiles[2])

# %%
df3 = df3.fillna('-9999')

# %%
  df3.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float64
# UV                       float64
# Par                      float64
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1         float64
# ElapsedTimeTudo            int64
# dtype: object

# %%
df3 = df3.apply(pd.to_numeric, axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2018-01-23 15:50:02"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-e7103836d583> in <module>
# ----> 1 df3 = df3.apply(pd.to_numeric, axis=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# ...

# %%
df3.dtypes
# Out:
# TIMESTAMP                 object
# RECORD                     int64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float64
# UV                       float64
# Par                      float64
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# wind_speed                object
# wind_direction            object
# DIF_GLO_REF_SPN1         float64
# ElapsedTimeTudo            int64
# dtype: object

# %%
df3= df3.convert_dtypes()

# %%
df3.dtypes
# Out:
# TIMESTAMP                 string
# RECORD                     Int64
# DNI_SHP1                 Float64
# LW_SGR4                  Float64
# GHIT_SMP22               Float64
# GHIP_SMP22               Float64
# GHIP_SMP11               Float64
# GHIP_SPN1                Float64
# GHIP_SI02pt100           Float64
# UV                       Float64
# Par                      Float64
# DfHIT_SMP22              Float64
# DfHIRP_SMP11             Float64
# DfHIP_SPN1               Float64
# TGIP_SMP11_VENT          Float64
# TGIP_SMP11_NoVen         Float64
# TGIP_SMP6_NoVen          Float64
# TGHIP_SI02pt100          Float64
# TGHIP_SI02pt100_dirty    Float64
# wind_speed                string
# wind_direction            string
# DIF_GLO_REF_SPN1         Float64
# ElapsedTimeTudo            Int64
# dtype: object

# %%
df3 = df3.astype('float64',errors = 'ignore').dtypes

# %%
df3.dtypes
# Out:
# dtype('O')

# %%
df3
# Out:
# TIMESTAMP                 string
# RECORD                   float64
# DNI_SHP1                 float64
# LW_SGR4                  float64
# GHIT_SMP22               float64
# GHIP_SMP22               float64
# GHIP_SMP11               float64
# GHIP_SPN1                float64
# GHIP_SI02pt100           float64
# UV                       float64
# Par                      float64
# DfHIT_SMP22              float64
# DfHIRP_SMP11             float64
# DfHIP_SPN1               float64
# TGIP_SMP11_VENT          float64
# TGIP_SMP11_NoVen         float64
# TGIP_SMP6_NoVen          float64
# TGHIP_SI02pt100          float64
# TGHIP_SI02pt100_dirty    float64
# wind_speed               float64
# wind_direction           float64
# DIF_GLO_REF_SPN1         float64
# ElapsedTimeTudo          float64
# dtype: object

# %%
   df['TIMESTAMP'] = df['TIMESTAMP'].astype(np.datetime64)
