# %%
from numba.core.extending import get_cython_function_address
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import datetime
import pytz
import pvlib

main_path = "/Users/nataly/opt/AnacondaProjects/SAPIENS/CLEAN/" 
BSRN_path = "/Users/nataly/opt/AnacondaProjects/SAPIENS/BSRN/"

# %%
months = ['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
          '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
          '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12',
          '2021-01']

years = ['2018', '2019', '2020', '2021']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1546300800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
date
# Out:
# '2019-01-01'

# %%
df = dfghi['GHIP_SI02pt100']

# %%
df
# Out:
# TIMESTAMP
# 2018-01-01 00:00:00      0.006883
# 2018-01-01 00:01:00      0.006883
# 2018-01-01 00:02:00     -0.010817
# 2018-01-01 00:03:00     -0.001967
# 2018-01-01 00:04:00      0.000000
#                           ...
# 2018-12-31 17:16:00    906.233333
# 2018-12-31 17:17:00    884.666667
# 2018-12-31 17:18:00    924.616667
# 2018-12-31 17:19:00    859.636667
# 2018-12-31 17:20:00    872.600000
# Freq: T, Name: GHIP_SI02pt100, Length: 525201, dtype: float64

# %%
date = '2018-08-01'

# %%
df.loc[date].plot()
figname = 'GHI'+ date +'.jpeg'
#fig = ghiplot.get_figure()
fig.savefig(figname)

# %%
months18 = ['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12']

months19 = ['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12']

months20 = ['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']

months21 = ['2021-01']


years = ['2018', '2019', '2020', '2021']

# %%
dfghi18 = pd.read_pickle(main_path+'2018GHI.pkl')
dfghi18 = dfghi18.resample('3Min').mean()  

for month in months18:
       df = dfghi['GHIP_SI02pt100']
       date = month +'-01'
       plt.figure()
       df.loc[date].plot()
       figname = 'GHI '+ date + '.jpeg'
       plt.savefig(figname)

# %%
dfghi19 = pd.read_pickle(main_path+'2019GHI.pkl')
dfghi19 = dfghi19.resample('3Min').mean()  

for month in months19:
       df = dfghi['GHIP_SI02pt100']
       date = month +'-01'
       plt.figure()
       df.loc[date].plot()
       figname = 'GHI '+ date + '.jpeg'
       plt.savefig(figname)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1546300800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
dfghi20 = pd.read_pickle(main_path+'2020GHI.pkl')
dfghi20 = dfghi20.resample('3Min').mean()  

for month in months20:
       df = dfghi['GHIP_SI02pt100']
       date = month +'-01'
       plt.figure()
       df.loc[date].plot()
       figname = 'GHI '+ date + '.jpeg'
       plt.savefig(figname)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1577836800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# ...

# %%
dfghi20
# Out:
#                      GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  GHIP_SPN1  \
# TIMESTAMP
# 2020-01-01 00:00:00       -0.001989   -2.823596    0.298876   2.571522
# 2020-01-01 00:03:00       -0.000656   -2.796667    0.399444   2.415044
# 2020-01-01 00:06:00       -0.001648   -2.663128    0.411173   2.516704
# 2020-01-01 00:09:00        0.000000   -2.539444    0.445556   2.499089
# 2020-01-01 00:12:00       -0.000656   -2.660000    0.401667   2.692278
# ...                             ...         ...         ...        ...
# 2020-12-31 23:45:00        0.000000   -4.803333    0.581111   2.500606
# 2020-12-31 23:48:00       -0.000328   -4.793889    0.600000   2.500750
# 2020-12-31 23:51:00       -0.000328   -4.575556    0.635556   2.394978
# 2020-12-31 23:54:00       -0.000328   -4.726667    0.687222   2.460089
# 2020-12-31 23:57:00        0.000000   -4.797778    0.611667   2.498161
#
#                      GHIT_SMP22
# TIMESTAMP
# 2020-01-01 00:00:00   -3.842697
# ...

# %%
       df = dfghi['GHIP_SI02pt100']

# %%
 month
# Out:
# '2020-01'

# %%
date = month +'-01'

# %%
date
# Out:
# '2020-01-01'

# %%
df.loc('2020-01-01')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: '2020-01-01'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-faf5ab15ec56> in <module>
# ----> 1 df.loc('2020-01-01')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# ...

# %%
    plt.figure()
       df.loc[date].plot()
       figname = 'GHI '+ date + '.jpeg'
       plt.savefig(figname)

# %%
dfghi20
# Out:
#                      GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  GHIP_SPN1  \
# TIMESTAMP
# 2020-01-01 00:00:00       -0.001989   -2.823596    0.298876   2.571522
# 2020-01-01 00:03:00       -0.000656   -2.796667    0.399444   2.415044
# 2020-01-01 00:06:00       -0.001648   -2.663128    0.411173   2.516704
# 2020-01-01 00:09:00        0.000000   -2.539444    0.445556   2.499089
# 2020-01-01 00:12:00       -0.000656   -2.660000    0.401667   2.692278
# ...                             ...         ...         ...        ...
# 2020-12-31 23:45:00        0.000000   -4.803333    0.581111   2.500606
# 2020-12-31 23:48:00       -0.000328   -4.793889    0.600000   2.500750
# 2020-12-31 23:51:00       -0.000328   -4.575556    0.635556   2.394978
# 2020-12-31 23:54:00       -0.000328   -4.726667    0.687222   2.460089
# 2020-12-31 23:57:00        0.000000   -4.797778    0.611667   2.498161
#
#                      GHIT_SMP22
# TIMESTAMP
# 2020-01-01 00:00:00   -3.842697
# ...

# %%
dfghi18
# Out:
#                      GHIP_SI02pt100   GHIP_SMP11   GHIP_SMP22    GHIP_SPN1  \
# TIMESTAMP
# 2018-01-01 00:00:00        0.000983    -2.189444     0.300000     1.501528
# 2018-01-01 00:03:00       -0.003933    -2.686667     0.167222     2.061033
# 2018-01-01 00:06:00        0.000328    -4.265000    -0.203889     3.916494
# 2018-01-01 00:09:00       -0.001311    -5.637222    -0.778333     4.215511
# 2018-01-01 00:12:00        0.000000    -5.994444    -1.300000     3.774372
# ...                             ...          ...          ...          ...
# 2018-12-31 17:06:00      999.755556  1024.255556  1033.405556  1035.777778
# 2018-12-31 17:09:00      991.783333  1015.566667  1024.966667  1019.150000
# 2018-12-31 17:12:00      957.283333   980.859444   992.386667   969.499444
# 2018-12-31 17:15:00      882.045000   901.556111   912.967778   898.830000
# 2018-12-31 17:18:00      891.345600   911.872000   923.248000   908.064000
#
#                       GHIT_SMP22
# TIMESTAMP
# ...

# %%
dfghi20
# Out:
#                      GHIP_SI02pt100  GHIP_SMP11  GHIP_SMP22  GHIP_SPN1  \
# TIMESTAMP
# 2020-01-01 00:00:00       -0.001989   -2.823596    0.298876   2.571522
# 2020-01-01 00:03:00       -0.000656   -2.796667    0.399444   2.415044
# 2020-01-01 00:06:00       -0.001648   -2.663128    0.411173   2.516704
# 2020-01-01 00:09:00        0.000000   -2.539444    0.445556   2.499089
# 2020-01-01 00:12:00       -0.000656   -2.660000    0.401667   2.692278
# ...                             ...         ...         ...        ...
# 2020-12-31 23:45:00        0.000000   -4.803333    0.581111   2.500606
# 2020-12-31 23:48:00       -0.000328   -4.793889    0.600000   2.500750
# 2020-12-31 23:51:00       -0.000328   -4.575556    0.635556   2.394978
# 2020-12-31 23:54:00       -0.000328   -4.726667    0.687222   2.460089
# 2020-12-31 23:57:00        0.000000   -4.797778    0.611667   2.498161
#
#                      GHIT_SMP22
# TIMESTAMP
# 2020-01-01 00:00:00   -3.842697
# ...
